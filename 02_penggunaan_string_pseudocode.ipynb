# %% [markdown]
# <a href="https://colab.research.google.com/github/maryantiayudwi-creator/PROJECT_ALPRO_GRUP_A/blob/main/02_penggunaan_string_pseudocode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```text
#
# START
#     Kalimat_1 = "Saya tak 'kan menyerah."
#     Kalimat_2 = 'Ia berkata, "Aku menyayangimu."'
#     Kalimat_3 = '"Coba jelaskan pengertian \'cross-validation\' dalam Machine Learning!"'
#     Kalimat_4 = "Surat keputusan itu bernomor 62/UN.34/19/2023."
#
#     PRINT Kalimat_1
#     PRINT Kalimat_2
#     PRINT Kalimat_3
#     PRINT Kalimat_4
# END
