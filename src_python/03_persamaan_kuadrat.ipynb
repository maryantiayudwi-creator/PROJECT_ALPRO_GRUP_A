# %% [markdown]
# <a href="https://colab.research.google.com/github/maryantiayudwi-creator/PROJECT_ALPRO_GRUP_A/blob/main/03_persamaan_kuadrat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# KASUS 1: Dua Akar Real Berbeda (D > 0)

# %%
import math

def hitung_akar_kuadrat():

    a = float(input("Masukkan nilai koefisien a: "))
    b = float(input("Masukkan nilai koefisien b: "))
    c = float(input("Masukkan nilai koefisien c: "))

    if a == 0:
        print("Nilai 'a' tidak boleh 0 karena ini bukan persamaan kuadrat.")
        return

    D = b**2 - 4*a*c

    print(f"\nNilai Diskriminan (D) = {D}")

    if D > 0:
        x1 = (-b + math.sqrt(D)) / (2*a)
        x2 = (-b - math.sqrt(D)) / (2*a)
        print("Persamaan memiliki DUA AKAR REAL yang berbeda:")
        print(f"x1 = {x1:.3f}")
        print(f"x2 = {x2:.3f}")

    elif D == 0:
        x = -b / (2*a)
        print("Persamaan memiliki SATU AKAR REAL (kembar):")
        print(f"x = {x:.3f}")

    else:
        print("Persamaan tersebut HANYA memiliki akar-akar imajiner.")

if __name__ == "__main__":
    hitung_akar_kuadrat()
# Out:
# Masukkan nilai koefisien a: 2
# Masukkan nilai koefisien b: 8
# Masukkan nilai koefisien c: 3
#
# Nilai Diskriminan (D) = 40.0
# Persamaan memiliki DUA AKAR REAL yang berbeda:
# x1 = -0.419
# x2 = -3.581

# %% [markdown]
# KASUS 2: Satu Akar Real / Kembar (D = 0)

# %%
import math

def hitung_akar_kuadrat():

    a = float(input("Masukkan nilai koefisien a: "))
    b = float(input("Masukkan nilai koefisien b: "))
    c = float(input("Masukkan nilai koefisien c: "))

    if a == 0:
        print("Nilai 'a' tidak boleh 0 karena ini bukan persamaan kuadrat.")
        return

    D = b**2 - 4*a*c

    print(f"\nNilai Diskriminan (D) = {D}")

    if D > 0:
        x1 = (-b + math.sqrt(D)) / (2*a)
        x2 = (-b - math.sqrt(D)) / (2*a)
        print("Persamaan memiliki DUA AKAR REAL yang berbeda:")
        print(f"x1 = {x1:.3f}")
        print(f"x2 = {x2:.3f}")

    elif D == 0:
        x = -b / (2*a)
        print("Persamaan memiliki SATU AKAR REAL (kembar):")
        print(f"x = {x:.3f}")

    else:
        print("Persamaan tersebut HANYA memiliki akar-akar imajiner.")

if __name__ == "__main__":
    hitung_akar_kuadrat()
# Out:
# Masukkan nilai koefisien a: 2
# Masukkan nilai koefisien b: -8
# Masukkan nilai koefisien c: 8
#
# Nilai Diskriminan (D) = 0.0
# Persamaan memiliki SATU AKAR REAL (kembar):
# x = 2.000

# %% [markdown]
#  KASUS 3: Akar Imajiner (D < 0)

# %%
import math

def hitung_akar_kuadrat():

    a = float(input("Masukkan nilai koefisien a: "))
    b = float(input("Masukkan nilai koefisien b: "))
    c = float(input("Masukkan nilai koefisien c: "))

    if a == 0:
        print("Nilai 'a' tidak boleh 0 karena ini bukan persamaan kuadrat.")
        return

    D = b**2 - 4*a*c

    print(f"\nNilai Diskriminan (D) = {D}")

    if D > 0:
        x1 = (-b + math.sqrt(D)) / (2*a)
        x2 = (-b - math.sqrt(D)) / (2*a)
        print("Persamaan memiliki DUA AKAR REAL yang berbeda:")
        print(f"x1 = {x1:.3f}")
        print(f"x2 = {x2:.3f}")

    elif D == 0:
        x = -b / (2*a)
        print("Persamaan memiliki SATU AKAR REAL (kembar):")
        print(f"x = {x:.3f}")

    else:
        print("Persamaan tersebut HANYA memiliki akar-akar imajiner.")

if __name__ == "__main__":
    hitung_akar_kuadrat()
# Out:
# Masukkan nilai koefisien a: 3
# Masukkan nilai koefisien b: 4
# Masukkan nilai koefisien c: 2
#
# Nilai Diskriminan (D) = -8.0
# Persamaan tersebut HANYA memiliki akar-akar imajiner.
