# %% [markdown]
# <a href="https://colab.research.google.com/github/maryantiayudwi-creator/PROJECT_ALPRO_GRUP_A/blob/main/02_string_kalimat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Kalimat_1 = "Saya tak 'kan menyerah."
Kalimat_2 = 'Ia berkata, "Aku menyayangimu."'
Kalimat_3 = '"Coba jelaskan pengertian \'cross-validation\' dalam Machine Learning!"'
Kalimat_4 = "Surat keputusan itu bernomor 62/UN.34/19/2023."

print(Kalimat_1)
print(Kalimat_2)
print(Kalimat_3)
print(Kalimat_4)
# Out:
# Saya tak 'kan menyerah.
# Ia berkata, "Aku menyayangimu."
# "Coba jelaskan pengertian 'cross-validation' dalam Machine Learning!"
# Surat keputusan itu bernomor 62/UN.34/19/2023.
