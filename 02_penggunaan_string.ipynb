# %% [markdown]
# <a href="https://colab.research.google.com/github/maryantiayudwi-creator/PROJECT_ALPRO_GRUP_A/blob/main/02_penggunaan_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```text
#
#
# START
#     K1 = "Saya tak 'kan menyerah."
#     K2 = 'Ia berkata, "Aku menyayangimu."'
#     K3 = '"Coba jelaskan pengertian \'cross-validation\' dalam Machine Learning!"'
#     K4 = "Surat keputusan itu bernomor 62/UN.34/19/2023."
#
#     TAMPILKAN K1
#     TAMPILKAN K2
#     TAMPILKAN K3
#     TAMPILKAN K4
# END
